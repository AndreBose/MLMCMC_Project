# %% [markdown]
# ## Import Modules

# %%
# Import modules

import os as os
import warnings

import sys
import time
import arviz             as az
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import numpy             as np
import pandas            as pd
from sklearn.decomposition import PCA
from scipy.interpolate import interp2d
from scipy.interpolate import RectBivariateSpline
import tensorflow as tf
import time

plt.style.use('seaborn')

np.random.seed(1234)
tf.random.set_seed(1234)

# %% [markdown]
# ## Settings

# %%
domain_dim = 2    # dimension of the domain of the PDE
params_dim = 2    # number of parameters

x_0 = np.array([0.5,0.5])   # center of the force

boundary  = lambda x: 0 * x[:,0]
forcing   = lambda x: 10 * np.exp(-50 * np.sqrt( np.power(x[:,0] - x_0[0], 2) + np.power(x[:,1] - x_0[1], 2) ))

train_split = 0.9     # Tentative proportion of training points wrt validation points

on_Colab = True
my_Colab_folder = "Colab Notebooks/Keras_Experiment"

# %% [markdown]
# ## Load data

# %%
if(on_Colab):
  from google.colab import drive
  drive.mount('/content/drive')

  folder = os.path.join('/content/drive/My Drive', my_Colab_folder)

if(not on_Colab):

  folder = os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_tables = os.path.join(folder, 'tables')

data_int = pd.read_csv (os.path.join(path_to_tables, 'tab_int.csv'), names = ('x','y','mu','theta','u'))
data_bc  = pd.read_csv (os.path.join(path_to_tables, 'tab_bc.csv' ), names = ('x','y','mu','theta','u'))

data_all = pd.concat([data_int,data_bc])

# Values of mu and theta
mus    = data_all   ['mu'].unique()
thetas = data_all['theta'].unique()


# Physical points
x_all  = data_all.loc[(data_all['mu'] == mus[0]) & (data_all['theta'] == thetas[0])][['x','y']].to_numpy()
x_int  = data_int.loc[(data_int['mu'] == mus[0]) & (data_int['theta'] == thetas[0])][['x','y']].to_numpy()
x_bc   = data_bc.loc [(data_bc ['mu'] == mus[0]) & (data_bc ['theta'] == thetas[0])][['x','y']].to_numpy()

# Dimension of the Matrix
n = x_all.shape[0]
p = len(mus) * len(thetas)

# %% [markdown]
# ## Reshape Data

# %%
# Reshaped dataset and parameters
data_all_reshaped = data_all.loc[(data_all['mu'] == mus[0]) & (data_all['theta'] == thetas[0])][['u']].to_numpy()

p_all = np.array(([[mus[0],thetas[0]]]))

for mu in mus:
    for theta in thetas:
        if ((mu != mus[0]) | (theta != thetas[0])):
            
            p_current = np.array(([[mu,theta]]))
            u_current = data_all.loc[(data_all['mu'] == mu) & (data_all['theta'] == theta)][['u']].to_numpy()
            
            p_all = np.concatenate((p_all, p_current), axis = 0)
            data_all_reshaped = np.concatenate((data_all_reshaped, u_current), axis = 1)

# %% [markdown]
# ## Build Model

# %%
model = tf.keras.Sequential([
                            tf.keras.layers.Dense(40, input_shape=(domain_dim+params_dim,), activation=tf.nn.tanh),
                            tf.keras.layers.Dense(40, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(40, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(1)
                            ])

# %% [markdown]
# ## Build Train and Validation datasets

# %%
u_max = np.max(data_all['u'])
u_min = np.min(data_all['u'])
print(u_max)
print(u_min)

train_data = data_all.sample(frac=train_split)
test_data = data_all.drop(train_data.index)

train_x_p = train_data[['x','y','mu','theta']].to_numpy()
test_x_p  = test_data [['x','y','mu','theta']].to_numpy()

train_u = (train_data['u'].to_numpy() - u_min)/(u_max - u_min)
test_u = (test_data['u'].to_numpy() - u_min)/(u_max - u_min)

train_dataset = tf.data.Dataset.from_tensor_slices((train_x_p,train_u))
test_dataset = tf.data.Dataset.from_tensor_slices((test_x_p,test_u))

print('________')
print(train_data.shape)
print(test_data.shape)
# Out:
# 0.0057748999999999995
# -1.1669000000000001e-05
# ________
# (392040, 5)
# (34342, 5)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Set number of epochs

# %%
ep1 = 60                # number of epochs first training
ep2 = 60                # number of epochs second training
second_train = True     # true if I want to perform two consecutive trainings

# %% [markdown]
# ### Compile the model for the first training

# %%
model.compile(loss=tf.losses.mean_squared_error,
             optimizer=tf.optimizers.Adam(learning_rate=1e-3)   
             # optimizer=tf.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
             )

# %% [markdown]
# ### First training

# %%
t_start = time.time()

hh1 = model.fit(x=train_x_p,
                y=train_u,
                epochs=ep1,
                batch_size=64,
                validation_data=(test_x_p,test_u))

train_time = time.time() - t_start
# Out:
# Epoch 1/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 0.0016 - val_loss: 4.5855e-04
# Epoch 2/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 9.1798e-04 - val_loss: 2.3789e-04
# Epoch 3/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.4292e-04 - val_loss: 2.3201e-04
# Epoch 4/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 5.0563e-04 - val_loss: 1.2465e-04
# Epoch 5/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 4.0917e-04 - val_loss: 2.6296e-04
# Epoch 6/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 3.5016e-04 - val_loss: 1.3981e-04
# Epoch 7/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 3.0327e-04 - val_loss: 9.2505e-05
# Epoch 8/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.6572e-04 - val_loss: 1.2381e-04
# Epoch 9/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.3978e-04 - val_loss: 5.5975e-05
# Epoch 10/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.0875e-04 - val_loss: 6.4547e-05
# Epoch 11/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9340e-04 - val_loss: 2.9066e-04
# Epoch 12/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.7952e-04 - val_loss: 7.0403e-05
# Epoch 13/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.6538e-04 - val_loss: 6.9283e-05
# Epoch 14/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.5024e-04 - val_loss: 4.2143e-05
# Epoch 15/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.4601e-04 - val_loss: 9.2783e-05
# Epoch 16/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.3543e-04 - val_loss: 2.9374e-05
# Epoch 17/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.3109e-04 - val_loss: 7.7038e-05
# Epoch 18/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.2356e-04 - val_loss: 5.4393e-05
# Epoch 19/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.1995e-04 - val_loss: 3.9839e-05
# Epoch 20/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1521e-04 - val_loss: 2.9957e-05
# Epoch 21/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0728e-04 - val_loss: 3.4516e-05
# Epoch 22/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0518e-04 - val_loss: 2.7363e-05
# Epoch 23/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 9.9593e-05 - val_loss: 3.6317e-05
# Epoch 24/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 9.7695e-05 - val_loss: 5.8658e-05
# Epoch 25/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 9.4149e-05 - val_loss: 4.0136e-05
# Epoch 26/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 9.2559e-05 - val_loss: 3.5946e-05
# Epoch 27/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 8.8150e-05 - val_loss: 3.8997e-05
# Epoch 28/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.8872e-05 - val_loss: 8.0299e-05
# Epoch 29/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 8.8164e-05 - val_loss: 2.7273e-05
# Epoch 30/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.9039e-05 - val_loss: 1.5675e-04
# Epoch 31/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 8.4641e-05 - val_loss: 6.1216e-05
# Epoch 32/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 8.2308e-05 - val_loss: 3.2356e-05
# Epoch 33/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.9173e-05 - val_loss: 2.3493e-05
# Epoch 34/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 8.0081e-05 - val_loss: 4.6264e-05
# Epoch 35/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 7.9982e-05 - val_loss: 1.9392e-05
# Epoch 36/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 7.5740e-05 - val_loss: 3.2557e-05
# Epoch 37/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 7.6202e-05 - val_loss: 3.7029e-05
# Epoch 38/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.3102e-05 - val_loss: 2.2108e-05
# Epoch 39/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 7.4128e-05 - val_loss: 8.5314e-05
# Epoch 40/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 7.7922e-05 - val_loss: 2.7509e-05
# Epoch 41/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.2101e-05 - val_loss: 3.3895e-05
# Epoch 42/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 7.1651e-05 - val_loss: 2.4871e-05
# Epoch 43/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.6527e-05 - val_loss: 2.4419e-05
# Epoch 44/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.4956e-05 - val_loss: 7.6010e-05
# Epoch 45/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.3599e-05 - val_loss: 3.7526e-05
# Epoch 46/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.7144e-05 - val_loss: 4.2722e-05
# Epoch 47/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.5543e-05 - val_loss: 5.3830e-05
# Epoch 48/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.8023e-05 - val_loss: 3.0495e-05
# Epoch 49/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.4082e-05 - val_loss: 3.0241e-05
# Epoch 50/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.6685e-05 - val_loss: 2.1002e-05
# Epoch 51/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.4801e-05 - val_loss: 3.4673e-05
# Epoch 52/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.5456e-05 - val_loss: 2.3937e-05
# Epoch 53/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.1402e-05 - val_loss: 1.3520e-05
# Epoch 54/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 6.4837e-05 - val_loss: 2.1709e-05
# Epoch 55/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 5.8918e-05 - val_loss: 4.2373e-05
# Epoch 56/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.3420e-05 - val_loss: 6.8143e-05
# Epoch 57/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.0817e-05 - val_loss: 3.2004e-05
# Epoch 58/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.1836e-05 - val_loss: 2.1538e-05
# Epoch 59/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 5.9911e-05 - val_loss: 1.2842e-05
# Epoch 60/60
# 6126/6126 [==============================] - 12s 2ms/step - loss: 5.8505e-05 - val_loss: 2.2347e-05

# %% [markdown]
# ### Visualize results

# %%
# select which solution to plot
sample_try = 40

p_try = np.tile(p_all[sample_try,:],(n,1))
x_p_try = np.hstack((x_all, p_try))

u_try = data_all_reshaped[:,sample_try]                     # real solution

u_recon = model.predict(x_p_try)*(u_max - u_min) + u_min    # reconstructed solution

fig, ax = plt.subplots(1,2, figsize=(14,5))
ax = ax.ravel()

im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
ax[0].set_title('Real sol');
plt.colorbar(im, ax=ax[0])

im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
plt.colorbar(im, ax=ax[1])
ax[1].set_title('NN sol');

plt.savefig(os.path.join(folder,'Output'))

# %% [markdown]
# ### Loss visualization

# %%
print('________________')
print(f'\nTraining Runtime: {train_time} seconds')
print('________________')

full_loss = hh1.history['loss']
full_val_loss = hh1.history['val_loss']

fig, ax = plt.subplots(1,1, figsize=(8,5))
ax.plot(full_loss, color='dodgerblue')
ax.plot(full_val_loss, color='orange')
ax.set_yscale('log')
ax.set_title('Model Loss')
ax.set_ylabel('loss')
ax.set_xlabel('epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.tight_layout()

plt.savefig(os.path.join(folder,'Model_loss'))
# Out:
# ________________
#
# Training Runtime: 742.4693109989166 seconds
# ________________

# %% [markdown]
# ### (Eventually) perform a second training

# %%
if second_train:

    weights = model.get_weights()

    model.compile(loss=tf.losses.mean_squared_error,
                 # optimizer=tf.optimizers.Adadelta()                 
                 # optimizer=tf.optimizers.Adam(learning_rate=1e-3)   
                  optimizer=tf.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
                 )

    model.set_weights(weights)
    
    t_start = time.time()
    
    hh2 = model.fit(x=train_x_p,
                    y=train_u,
                    epochs=ep2,
                    batch_size=64,
                    validation_data=(test_x_p,test_u))
    
    train_time = time.time() - t_start
# Out:
# Epoch 1/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2
60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9236e-05 - val_loss: 7.3786e-06
# Epoch 55/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9143e-05 - val_loss: 7.5128e-06
# Epoch 56/60
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.9176e-05 - val_loss: 7.6252e-06
# Epoch 57/60
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.9087e-05 - val_loss: 7.6823e-06
# Epoch 58/60
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.9159e-05 - val_loss: 7.1924e-06
# Epoch 59/60
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9171e-05 - val_loss: 7.6567e-06
# Epoch 60/60
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.9001e-05 - val_loss: 7.4841e-06

# %%
if second_train:

    sample_try = 40

    p_try = np.tile(p_all[sample_try,:],(n,1))
    x_p_try = np.hstack((x_all, p_try))

    u_try = data_all_reshaped[:,sample_try]

    u_recon = model.predict(x_p_try)*(u_max - u_min) + u_min

    fig, ax = plt.subplots(1,2, figsize=(14,5))
    ax = ax.ravel()

    im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
    ax[0].set_title('Real sol');
    plt.colorbar(im, ax=ax[0])

    im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
    plt.colorbar(im, ax=ax[1])
    ax[1].set_title('NN sol');

    plt.savefig(os.path.join(folder,'Output_second'))

# %%
 if second_train:  
        
    print('________________')
    print(f'\nTraining Runtime: {train_time} seconds')
    print('________________')
    
    full_loss = hh1.history['loss'] + hh2.history['loss']
    full_val_loss = hh1.history['val_loss'] + hh2.history['val_loss']

    fig, ax = plt.subplots(1,1, figsize=(8,5))
    ax.plot(full_loss, color='dodgerblue')
    ax.plot(full_val_loss, color='orange')
    ax.axvline(x=(ep1-1), color='red', linestyle='--')
    ax.set_yscale('log')
    ax.set_title('Model Loss')
    ax.set_ylabel('loss')
    ax.set_xlabel('epoch')
    plt.legend(['Train', 'Test'], loc='best')

    plt.tight_layout()

    plt.savefig(os.path.join(folder,'Model_loss_second'))
# Out:
# ________________
#
# Training Runtime: 622.3564801216125 seconds
# ________________

# %% [markdown]
# ## Save the model

# %%
model.save(os.path.join(folder,'red_model0'))
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Keras_Experiment/red_model0/assets

# %%
folder
# Out:
# '/content/drive/My Drive/Colab Notebooks/Keras_Experiment'

# %% [markdown]
# ## Load a previously saved model

# %%
"""
load_model = tf.keras.models.load_model('red_model04')

sample_try = 40
print(p_all[sample_try,:])
p_try = np.tile(p_all[sample_try,:],(n,1))
x_p_try = np.hstack((x_all, p_try))

u_try = data_all_reshaped[:,sample_try]

u_recon = load_model.predict(x_p_try)*(u_max - u_min) + u_min

fig, ax = plt.subplots(1,2, figsize=(14,5))
ax = ax.ravel()

im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
ax[0].set_title('Real sol');
plt.colorbar(im, ax=ax[0])

im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
plt.colorbar(im, ax=ax[1])
ax[1].set_title('NN sol');

plt.savefig(os.path.join(folder,'Output'))

"""
# Out:
# "\nload_model = tf.keras.models.load_model('red_model04')\n\nsample_try = 40\nprint(p_all[sample_try,:])\np_try = np.tile(p_all[sample_try,:],(n,1))\nx_p_try = np.hstack((x_all, p_try))\n\nu_try = data_all_reshaped[:,sample_try]\n\nu_recon = load_model.predict(x_p_try)*(u_max - u_min) + u_min\n\nfig, ax = plt.subplots(1,2, figsize=(14,5))\nax = ax.ravel()\n\nim = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')\nax[0].set_title('Real sol');\nplt.colorbar(im, ax=ax[0])\n\nim = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');\nplt.colorbar(im, ax=ax[1])\nax[1].set_title('NN sol');\n\nplt.savefig(os.path.join(folder,'Output'))\n\n"
