# %% [markdown]
# ## Import Modules

# %%
# Import modules

import os as os
import warnings

import sys
import time
import arviz             as az
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import numpy             as np
import pandas            as pd
from sklearn.decomposition import PCA
from scipy.interpolate import interp2d
from scipy.interpolate import RectBivariateSpline
import tensorflow as tf
import time

plt.style.use('seaborn')

np.random.seed(1234)
tf.random.set_seed(1234)

# %% [markdown]
# ## Settings

# %%
domain_dim = 2    # dimension of the domain of the PDE
params_dim = 2    # number of parameters

x_0 = np.array([0.5,0.5])   # center of the force

boundary  = lambda x: 0 * x[:,0]
forcing   = lambda x: 10 * np.exp(-50 * np.sqrt( np.power(x[:,0] - x_0[0], 2) + np.power(x[:,1] - x_0[1], 2) ))

train_split = 0.9     # Tentative proportion of training points wrt validation points

on_Colab = True
my_Colab_folder = "Colab Notebooks/Keras_Experiment"

# %% [markdown]
# ## Load data

# %%
if(on_Colab):
  from google.colab import drive
  drive.mount('/content/drive')

  folder = os.path.join('/content/drive/My Drive', my_Colab_folder)

if(not on_Colab):

  folder = os.getcwd()
# Out:
# Mounted at /content/drive

# %%
path_to_tables = os.path.join(folder, 'tables')

data_int = pd.read_csv (os.path.join(path_to_tables, 'tab_int.csv'), names = ('x','y','mu','theta','u'))
data_bc  = pd.read_csv (os.path.join(path_to_tables, 'tab_bc.csv' ), names = ('x','y','mu','theta','u'))

data_all = pd.concat([data_int,data_bc])

# Values of mu and theta
mus    = data_all   ['mu'].unique()
thetas = data_all['theta'].unique()


# Physical points
x_all  = data_all.loc[(data_all['mu'] == mus[0]) & (data_all['theta'] == thetas[0])][['x','y']].to_numpy()
x_int  = data_int.loc[(data_int['mu'] == mus[0]) & (data_int['theta'] == thetas[0])][['x','y']].to_numpy()
x_bc   = data_bc.loc [(data_bc ['mu'] == mus[0]) & (data_bc ['theta'] == thetas[0])][['x','y']].to_numpy()

# Dimension of the Matrix
n = x_all.shape[0]
p = len(mus) * len(thetas)

# %% [markdown]
# ## Reshape Data

# %%
# Reshaped dataset and parameters
data_all_reshaped = data_all.loc[(data_all['mu'] == mus[0]) & (data_all['theta'] == thetas[0])][['u']].to_numpy()

p_all = np.array(([[mus[0],thetas[0]]]))

for mu in mus:
    for theta in thetas:
        if ((mu != mus[0]) | (theta != thetas[0])):
            
            p_current = np.array(([[mu,theta]]))
            u_current = data_all.loc[(data_all['mu'] == mu) & (data_all['theta'] == theta)][['u']].to_numpy()
            
            p_all = np.concatenate((p_all, p_current), axis = 0)
            data_all_reshaped = np.concatenate((data_all_reshaped, u_current), axis = 1)

# %% [markdown]
# ## Build Model

# %%
model = tf.keras.Sequential([
                            tf.keras.layers.Dense(50, input_shape=(domain_dim+params_dim,), activation=tf.nn.tanh),
                            tf.keras.layers.Dense(50, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(50, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(50, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(1)
                            ])

# %% [markdown]
# ## Build Train and Validation datasets

# %%
u_max = np.max(data_all['u'])
u_min = np.min(data_all['u'])
print(u_max)
print(u_min)

train_data = data_all.sample(frac=train_split)
test_data = data_all.drop(train_data.index)

train_x_p = train_data[['x','y','mu','theta']].to_numpy()
test_x_p  = test_data [['x','y','mu','theta']].to_numpy()

train_u = (train_data['u'].to_numpy() - u_min)/(u_max - u_min)
test_u = (test_data['u'].to_numpy() - u_min)/(u_max - u_min)

train_dataset = tf.data.Dataset.from_tensor_slices((train_x_p,train_u))
test_dataset = tf.data.Dataset.from_tensor_slices((test_x_p,test_u))

print('________')
print(train_data.shape)
print(test_data.shape)
# Out:
# 0.0057748999999999995
# -1.1669000000000001e-05
# ________
# (392040, 5)
# (34342, 5)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Set number of epochs

# %%
ep1 = 100               # number of epochs first training
ep2 =  50               # number of epochs second training
second_train = True     # true if I want to perform two consecutive trainings

# %% [markdown]
# ### Compile the model for the first training

# %%
model.compile(loss=tf.losses.mean_squared_error,
             optimizer=tf.optimizers.Adam(learning_rate=1e-3)   
             # optimizer=tf.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
             )

# %% [markdown]
# ### First training

# %%
t_start = time.time()

hh1 = model.fit(x=train_x_p,
                y=train_u,
                epochs=ep1,
                batch_size=64,
                validation_data=(test_x_p,test_u))

train_time = time.time() - t_start
# Out:
# Epoch 1/100
# 6126/6126 [==============================] - 14s 2ms/step - loss: 0.0015 - val_loss: 5.2648e-04
# Epoch 2/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.1130e-04 - val_loss: 2.7496e-04
# Epoch 3/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.4281e-04 - val_loss: 2.9258e-04
# Epoch 4/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 4.2550e-04 - val_loss: 2.6087e-04
# Epoch 5/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 3.4560e-04 - val_loss: 1.9589e-04
# Epoch 6/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 3.0420e-04 - val_loss: 1.0336e-04
# Epoch 7/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 2.7902e-04 - val_loss: 1.2849e-04
# Epoch 8/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 2.3280e-04 - val_loss: 1.0732e-04
# Epoch 9/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 2.1925e-04 - val_loss: 8.9976e-05
# Epoch 10/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 2.0342e-04 - val_loss: 6.7597e-05
# Epoch 11/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.9005e-04 - val_loss: 4.6861e-04
# Epoch 12/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.7242e-04 - val_loss: 6.9933e-05
# Epoch 13/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.6199e-04 - val_loss: 4.6138e-05
# Epoch 14/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.4184e-04 - val_loss: 2.7492e-05
# Epoch 15/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.6119e-04 - val_loss: 6.3089e-05
# Epoch 16/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.5255e-04 - val_loss: 2.9227e-05
# Epoch 17/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.4906e-04 - val_loss: 4.0855e-05
# Epoch 18/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.2786e-04 - val_loss: 6.1893e-05
# Epoch 19/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.2942e-04 - val_loss: 3.4338e-05
# Epoch 20/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.1197e-04 - val_loss: 1.1676e-04
# Epoch 21/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.2367e-04 - val_loss: 3.0088e-05
# Epoch 22/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.1606e-04 - val_loss: 3.3496e-05
# Epoch 23/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.1640e-04 - val_loss: 1.5707e-04
# Epoch 24/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.0909e-04 - val_loss: 4.9206e-05
# Epoch 25/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0479e-04 - val_loss: 6.7491e-05
# Epoch 26/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0978e-04 - val_loss: 3.2995e-05
# Epoch 27/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0009e-04 - val_loss: 2.1642e-05
# Epoch 28/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.0953e-04 - val_loss: 2.8888e-05
# Epoch 29/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 9.6385e-05 - val_loss: 2.5976e-05
# Epoch 30/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0703e-04 - val_loss: 1.0902e-04
# Epoch 31/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.8019e-05 - val_loss: 2.6670e-05
# Epoch 32/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.1005e-04 - val_loss: 1.1236e-04
# Epoch 33/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.6480e-05 - val_loss: 4.1361e-05
# Epoch 34/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.7491e-05 - val_loss: 2.5839e-05
# Epoch 35/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.4799e-05 - val_loss: 2.5202e-05
# Epoch 36/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.5295e-05 - val_loss: 4.7441e-05
# Epoch 37/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.9747e-05 - val_loss: 2.0859e-05
# Epoch 38/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.1944e-05 - val_loss: 1.6884e-05
# Epoch 39/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.8368e-05 - val_loss: 1.2523e-05
# Epoch 40/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.4700e-05 - val_loss: 2.5985e-05
# Epoch 41/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.9336e-05 - val_loss: 7.9341e-05
# Epoch 42/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.4474e-05 - val_loss: 4.1116e-05
# Epoch 43/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 9.0679e-05 - val_loss: 1.5476e-05
# Epoch 44/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.7448e-05 - val_loss: 8.9231e-05
# Epoch 45/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.9832e-05 - val_loss: 2.4558e-05
# Epoch 46/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.5762e-05 - val_loss: 7.0907e-05
# Epoch 47/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.1619e-05 - val_loss: 2.8167e-05
# Epoch 48/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.3304e-05 - val_loss: 5.8267e-05
# Epoch 49/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.6453e-05 - val_loss: 3.6162e-05
# Epoch 50/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.2913e-05 - val_loss: 1.6855e-05
# Epoch 51/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.2693e-05 - val_loss: 3.8119e-05
# Epoch 52/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.3418e-05 - val_loss: 3.1080e-05
# Epoch 53/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.5939e-05 - val_loss: 1.4929e-05
# Epoch 54/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.9713e-05 - val_loss: 3.5859e-05
# Epoch 55/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 8.3205e-05 - val_loss: 3.0521e-05
# Epoch 56/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 8.1144e-05 - val_loss: 2.4710e-05
# Epoch 57/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.4366e-05 - val_loss: 1.5648e-05
# Epoch 58/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.6577e-05 - val_loss: 3.2402e-05
# Epoch 59/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.5994e-05 - val_loss: 3.2177e-05
# Epoch 60/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.4226e-05 - val_loss: 2.4147e-05
# Epoch 61/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.4102e-05 - val_loss: 5.7528e-05
# Epoch 62/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.7396e-05 - val_loss: 2.8011e-05
# Epoch 63/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.1538e-05 - val_loss: 1.0550e-04
# Epoch 64/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.4495e-05 - val_loss: 5.7505e-05
# Epoch 65/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.2250e-05 - val_loss: 9.4424e-06
# Epoch 66/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.2260e-05 - val_loss: 1.8693e-05
# Epoch 67/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.2058e-05 - val_loss: 1.5863e-05
# Epoch 68/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.4883e-05 - val_loss: 6.1364e-05
# Epoch 69/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.0815e-05 - val_loss: 2.9167e-05
# Epoch 70/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.3934e-05 - val_loss: 1.5097e-05
# Epoch 71/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.5888e-05 - val_loss: 1.4588e-05
# Epoch 72/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.0814e-05 - val_loss: 1.9885e-05
# Epoch 73/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.3474e-05 - val_loss: 2.5550e-05
# Epoch 74/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.2237e-05 - val_loss: 3.1578e-05
# Epoch 75/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.6483e-05 - val_loss: 2.7068e-05
# Epoch 76/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.0446e-05 - val_loss: 1.3524e-05
# Epoch 77/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.3506e-05 - val_loss: 1.5089e-05
# Epoch 78/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 7.1683e-05 - val_loss: 2.0138e-05
# Epoch 79/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.1347e-05 - val_loss: 1.4273e-05
# Epoch 80/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.7149e-05 - val_loss: 1.6497e-05
# Epoch 81/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.2528e-05 - val_loss: 4.1009e-05
# Epoch 82/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 7.8822e-05 - val_loss: 1.3563e-05
# Epoch 83/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 5.8146e-05 - val_loss: 2.1055e-05
# Epoch 84/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.7037e-05 - val_loss: 3.1872e-05
# Epoch 85/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.8811e-05 - val_loss: 1.8110e-05
# Epoch 86/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.2134e-05 - val_loss: 9.3232e-06
# Epoch 87/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.8593e-05 - val_loss: 1.5172e-05
# Epoch 88/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.3980e-05 - val_loss: 1.1904e-05
# Epoch 89/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.0338e-05 - val_loss: 3.1040e-05
# Epoch 90/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.2635e-05 - val_loss: 1.1105e-05
# Epoch 91/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.7031e-05 - val_loss: 1.0857e-05
# Epoch 92/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.1478e-05 - val_loss: 1.5891e-05
# Epoch 93/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.8009e-05 - val_loss: 2.7632e-05
# Epoch 94/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.7962e-05 - val_loss: 1.4736e-05
# Epoch 95/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.2614e-05 - val_loss: 3.6525e-05
# Epoch 96/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.5289e-05 - val_loss: 1.6378e-05
# Epoch 97/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.4937e-05 - val_loss: 5.2336e-05
# Epoch 98/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.5078e-05 - val_loss: 2.9748e-05
# Epoch 99/100
# 6126/6126 [==============================] - 13s 2ms/step - loss: 5.2952e-05 - val_loss: 2.2797e-05
# Epoch 100/100
# 6126/6126 [==============================] - 12s 2ms/step - loss: 6.3180e-05 - val_loss: 5.2512e-05

# %% [markdown]
# ### Visualize results

# %%
# select which solution to plot
sample_try = 40

p_try = np.tile(p_all[sample_try,:],(n,1))
x_p_try = np.hstack((x_all, p_try))

u_try = data_all_reshaped[:,sample_try]                     # real solution

u_recon = model.predict(x_p_try)*(u_max - u_min) + u_min    # reconstructed solution

fig, ax = plt.subplots(1,2, figsize=(14,5))
ax = ax.ravel()

im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
ax[0].set_title('Real sol');
plt.colorbar(im, ax=ax[0])

im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
plt.colorbar(im, ax=ax[1])
ax[1].set_title('NN sol');

plt.savefig(os.path.join(folder,'Output'))

# %% [markdown]
# ### Loss visualization

# %%
print('________________')
print(f'\nTraining Runtime: {train_time} seconds')
print('________________')

full_loss = hh1.history['loss']
full_val_loss = hh1.history['val_loss']

fig, ax = plt.subplots(1,1, figsize=(8,5))
ax.plot(full_loss, color='dodgerblue')
ax.plot(full_val_loss, color='orange')
ax.set_yscale('log')
ax.set_title('Model Loss')
ax.set_ylabel('loss')
ax.set_xlabel('epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.tight_layout()

plt.savefig(os.path.join(folder,'Model_loss'))
# Out:
# ________________
#
# Training Runtime: 1282.7286174297333 seconds
# ________________

# %% [markdown]
# ### (Eventually) perform a second training

# %%
if second_train:

    weights = model.get_weights()

    model.compile(loss=tf.losses.mean_squared_error,
                 # optimizer=tf.optimizers.Adadelta()                 
                 # optimizer=tf.optimizers.Adam(learning_rate=1e-3)   
                  optimizer=tf.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
                 )

    model.set_weights(weights)
    
    t_start = time.time()
    
    hh2 = model.fit(x=train_x_p,
                    y=train_u,
                    epochs=ep2,
                    batch_size=64,
                    validation_data=(test_x_p,test_u))
    
    train_time = time.time() - t_start
# Out:
# Epoch 1/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.6172e-05 - val_loss: 9.4126e-06
# Epoch 2/50
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.8772e-05 - val_loss: 8.0561e-06
# Epoch 3/50
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.7195e-05 - val_loss: 7.3232e-06
# Epoch 4/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.6014e-05 - val_loss: 7.3401e-06
# Epoch 5/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.5311e-05 - val_loss: 7.0842e-06
# Epoch 6/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.4719e-05 - val_loss: 6.5805e-06
# Epoch 7/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.4348e-05 - val_loss: 6.0539e-06
# Epoch 8/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.3956e-05 - val_loss: 5.8346e-06
# Epoch 9/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.3656e-05 - val_loss: 6.4538e-06
# Epoch 10/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.3270e-05 - val_loss: 5.8074e-06
# Epoch 11/50
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.3127e-05 - val_loss: 5.5981e-06
# Epoch 12/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.2861e-05 - val_loss: 5.5328e-06
# Epoch 13/50
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.2706e-05 - val_loss: 5.4320e-06
# Epoch 14/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.2548e-05 - val_loss: 5.7676e-06
# Epoch 15/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.2375e-05 - val_loss: 5.2625e-06
# Epoch 16/50
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.2267e-05 - val_loss: 5.0802e-06
# Epoch 17/50
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.2109e-05 - val_loss: 5.7420e-06
# Epoch 18/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.2142e-05 - val_loss: 5.1613e-06
# Epoch 19/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1851e-05 - val_loss: 6.5625e-06
# Epoch 20/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1829e-05 - val_loss: 4.8317e-06
# Epoch 21/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1725e-05 - val_loss: 5.2564e-06
# Epoch 22/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1626e-05 - val_loss: 5.5656e-06
# Epoch 23/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1527e-05 - val_loss: 4.8992e-06
# Epoch 24/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1420e-05 - val_loss: 4.9674e-06
# Epoch 25/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1304e-05 - val_loss: 4.9990e-06
# Epoch 26/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1300e-05 - val_loss: 5.0702e-06
# Epoch 27/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1224e-05 - val_loss: 4.8780e-06
# Epoch 28/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1070e-05 - val_loss: 4.6988e-06
# Epoch 29/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.1107e-05 - val_loss: 4.5788e-06
# Epoch 30/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0986e-05 - val_loss: 4.7008e-06
# Epoch 31/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0990e-05 - val_loss: 4.7644e-06
# Epoch 32/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0941e-05 - val_loss: 4.7190e-06
# Epoch 33/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0768e-05 - val_loss: 5.4737e-06
# Epoch 34/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0763e-05 - val_loss: 4.7196e-06
# Epoch 35/50
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0816e-05 - val_loss: 4.4595e-06
# Epoch 36/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0656e-05 - val_loss: 4.4748e-06
# Epoch 37/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0564e-05 - val_loss: 4.7349e-06
# Epoch 38/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0595e-05 - val_loss: 5.5831e-06
# Epoch 39/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0478e-05 - val_loss: 4.6721e-06
# Epoch 40/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0431e-05 - val_loss: 5.6506e-06
# Epoch 41/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0499e-05 - val_loss: 4.5332e-06
# Epoch 42/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0404e-05 - val_loss: 5.2997e-06
# Epoch 43/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0368e-05 - val_loss: 4.7059e-06
# Epoch 44/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0357e-05 - val_loss: 4.8260e-06
# Epoch 45/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0392e-05 - val_loss: 4.5166e-06
# Epoch 46/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0212e-05 - val_loss: 4.4151e-06
# Epoch 47/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0238e-05 - val_loss: 4.3739e-06
# Epoch 48/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0238e-05 - val_loss: 4.7141e-06
# Epoch 49/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0182e-05 - val_loss: 4.4351e-06
# Epoch 50/50
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.0136e-05 - val_loss: 4.3767e-06

# %%
if second_train:

    sample_try = 250

    p_try = np.tile(p_all[sample_try,:],(n,1))
    x_p_try = np.hstack((x_all, p_try))

    u_try = data_all_reshaped[:,sample_try]

    u_recon = model.predict(x_p_try)*(u_max - u_min) + u_min

    fig, ax = plt.subplots(1,2, figsize=(14,5))
    ax = ax.ravel()

    im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
    ax[0].set_title('Real sol');
    plt.colorbar(im, ax=ax[0])

    im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
    plt.colorbar(im, ax=ax[1])
    ax[1].set_title('NN sol');

    plt.savefig(os.path.join(folder,'Output_second'))

# %%
 if second_train:  
        
    print('________________')
    print(f'\nTraining Runtime: {train_time} seconds')
    print('________________')
    
    full_loss = hh1.history['loss'] + hh2.history['loss']
    full_val_loss = hh1.history['val_loss'] + hh2.history['val_loss']

    fig, ax = plt.subplots(1,1, figsize=(8,5))
    ax.plot(full_loss, color='dodgerblue')
    ax.plot(full_val_loss, color='orange')
    ax.axvline(x=(ep1-1), color='red', linestyle='--')
    ax.set_yscale('log')
    ax.set_title('Model Loss')
    ax.set_ylabel('loss')
    ax.set_xlabel('epoch')
    plt.legend(['Train', 'Test'], loc='best')

    plt.tight_layout()

    plt.savefig(os.path.join(folder,'Model_loss_second'))
# Out:
# ________________
#
# Training Runtime: 533.7982311248779 seconds
# ________________

# %% [markdown]
# ## Save the model

# %%
model.save(os.path.join(folder,'red_model0'))
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Keras_Experiment/red_model0/assets

# %%
folder
# Out:
# '/content/drive/My Drive/Colab Notebooks/Keras_Experiment'

# %% [markdown]
# ## Load a previously saved model

# %%
"""
load_model = tf.keras.models.load_model('red_model04')

sample_try = 40
print(p_all[sample_try,:])
p_try = np.tile(p_all[sample_try,:],(n,1))
x_p_try = np.hstack((x_all, p_try))

u_try = data_all_reshaped[:,sample_try]

u_recon = load_model.predict(x_p_try)*(u_max - u_min) + u_min

fig, ax = plt.subplots(1,2, figsize=(14,5))
ax = ax.ravel()

im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
ax[0].set_title('Real sol');
plt.colorbar(im, ax=ax[0])

im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
plt.colorbar(im, ax=ax[1])
ax[1].set_title('NN sol');

plt.savefig(os.path.join(folder,'Output'))

"""
# Out:
# "\nload_model = tf.keras.models.load_model('red_model04')\n\nsample_try = 40\nprint(p_all[sample_try,:])\np_try = np.tile(p_all[sample_try,:],(n,1))\nx_p_try = np.hstack((x_all, p_try))\n\nu_try = data_all_reshaped[:,sample_try]\n\nu_recon = load_model.predict(x_p_try)*(u_max - u_min) + u_min\n\nfig, ax = plt.subplots(1,2, figsize=(14,5))\nax = ax.ravel()\n\nim = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')\nax[0].set_title('Real sol');\nplt.colorbar(im, ax=ax[0])\n\nim = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');\nplt.colorbar(im, ax=ax[1])\nax[1].set_title('NN sol');\n\nplt.savefig(os.path.join(folder,'Output'))\n\n"
