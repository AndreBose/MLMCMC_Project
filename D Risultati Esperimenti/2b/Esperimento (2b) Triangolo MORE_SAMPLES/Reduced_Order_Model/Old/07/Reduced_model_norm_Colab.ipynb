# %% [markdown]
# ## Import Modules

# %%
# Import modules

import os as os
import warnings

import sys
import time
import arviz             as az
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import numpy             as np
import pandas            as pd
from sklearn.decomposition import PCA
from scipy.interpolate import interp2d
from scipy.interpolate import RectBivariateSpline
import tensorflow as tf
import time

plt.style.use('seaborn')

np.random.seed(1234)
tf.random.set_seed(1234)

# %% [markdown]
# ## Settings

# %%
domain_dim = 2    # dimension of the domain of the PDE
params_dim = 2    # number of parameters

x_0 = np.array([0.5,0.5])   # center of the force

boundary  = lambda x: 0 * x[:,0]
forcing   = lambda x: 10 * np.exp(-50 * np.sqrt( np.power(x[:,0] - x_0[0], 2) + np.power(x[:,1] - x_0[1], 2) ))

train_split = 0.9     # Tentative proportion of training points wrt validation points

on_Colab = True
my_Colab_folder = "Colab Notebooks/Keras_Experiment"

# %% [markdown]
# ## Load data

# %%
if(on_Colab):
  from google.colab import drive
  drive.mount('/content/drive')

  folder = os.path.join('/content/drive/My Drive', my_Colab_folder)

if(not on_Colab):

  folder = os.getcwd()
# Out:
# Mounted at /content/drive

# %%
path_to_tables = os.path.join(folder, 'tables')

data_int = pd.read_csv (os.path.join(path_to_tables, 'tab_int.csv'), names = ('x','y','mu','theta','u'))
data_bc  = pd.read_csv (os.path.join(path_to_tables, 'tab_bc.csv' ), names = ('x','y','mu','theta','u'))

data_all = pd.concat([data_int,data_bc])

# Values of mu and theta
mus    = data_all   ['mu'].unique()
thetas = data_all['theta'].unique()


# Physical points
x_all  = data_all.loc[(data_all['mu'] == mus[0]) & (data_all['theta'] == thetas[0])][['x','y']].to_numpy()
x_int  = data_int.loc[(data_int['mu'] == mus[0]) & (data_int['theta'] == thetas[0])][['x','y']].to_numpy()
x_bc   = data_bc.loc [(data_bc ['mu'] == mus[0]) & (data_bc ['theta'] == thetas[0])][['x','y']].to_numpy()

# Dimension of the Matrix
n = x_all.shape[0]
p = len(mus) * len(thetas)

# %% [markdown]
# ## Reshape Data

# %%
# Reshaped dataset and parameters
data_all_reshaped = data_all.loc[(data_all['mu'] == mus[0]) & (data_all['theta'] == thetas[0])][['u']].to_numpy()

p_all = np.array(([[mus[0],thetas[0]]]))

for mu in mus:
    for theta in thetas:
        if ((mu != mus[0]) | (theta != thetas[0])):
            
            p_current = np.array(([[mu,theta]]))
            u_current = data_all.loc[(data_all['mu'] == mu) & (data_all['theta'] == theta)][['u']].to_numpy()
            
            p_all = np.concatenate((p_all, p_current), axis = 0)
            data_all_reshaped = np.concatenate((data_all_reshaped, u_current), axis = 1)

# %% [markdown]
# ## Build Model

# %%
model = tf.keras.Sequential([
                            tf.keras.layers.Dense(50, input_shape=(domain_dim+params_dim,), activation=tf.nn.tanh),
                            tf.keras.layers.Dense(50, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(50, activation=tf.nn.tanh),
                            tf.keras.layers.Dense(1)
                            ])

# %% [markdown]
# ## Build Train and Validation datasets

# %%
u_max = np.max(data_all['u'])
u_min = np.min(data_all['u'])
print(u_max)
print(u_min)

train_data = data_all.sample(frac=train_split)
test_data = data_all.drop(train_data.index)

train_x_p = train_data[['x','y','mu','theta']].to_numpy()
test_x_p  = test_data [['x','y','mu','theta']].to_numpy()

train_u = (train_data['u'].to_numpy() - u_min)/(u_max - u_min)
test_u = (test_data['u'].to_numpy() - u_min)/(u_max - u_min)

train_dataset = tf.data.Dataset.from_tensor_slices((train_x_p,train_u))
test_dataset = tf.data.Dataset.from_tensor_slices((test_x_p,test_u))

print('________')
print(train_data.shape)
print(test_data.shape)
# Out:
# 0.0057748999999999995
# -1.1669000000000001e-05
# ________
# (392040, 5)
# (34342, 5)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Set number of epochs

# %%
ep1 = 70                # number of epochs first training
ep2 = 70                # number of epochs second training
second_train = True     # true if I want to perform two consecutive trainings

# %% [markdown]
# ### Compile the model for the first training

# %%
model.compile(loss=tf.losses.mean_squared_error,
             optimizer=tf.optimizers.Adam(learning_rate=1e-3)   
             # optimizer=tf.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
             )

# %% [markdown]
# ### First training

# %%
t_start = time.time()

hh1 = model.fit(x=train_x_p,
                y=train_u,
                epochs=ep1,
                batch_size=64,
                validation_data=(test_x_p,test_u))

train_time = time.time() - t_start
# Out:
# Epoch 1/70
# 6126/6126 [==============================] - 14s 2ms/step - loss: 0.0024 - val_loss: 5.8891e-04
# Epoch 2/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 0.0010 - val_loss: 3.7817e-04
# Epoch 3/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.9447e-04 - val_loss: 2.3098e-04
# Epoch 4/70
# 6126/6126 [==============================] - 14s 2ms/step - loss: 5.3185e-04 - val_loss: 1.6108e-04
# Epoch 5/70
# 6126/6126 [==============================] - 14s 2ms/step - loss: 4.2490e-04 - val_loss: 2.1224e-04
# Epoch 6/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 3.4391e-04 - val_loss: 1.3747e-04
# Epoch 7/70
# 6126/6126 [==============================] - 14s 2ms/step - loss: 2.8731e-04 - val_loss: 8.3006e-05
# Epoch 8/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 2.5137e-04 - val_loss: 1.3349e-04
# Epoch 9/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 2.3358e-04 - val_loss: 5.5895e-05
# Epoch 10/70
# 6126/6126 [==============================] - 14s 2ms/step - loss: 2.0917e-04 - val_loss: 1.2216e-04
# Epoch 11/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.9629e-04 - val_loss: 1.8142e-04
# Epoch 12/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.8520e-04 - val_loss: 6.9435e-05
# Epoch 13/70
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.6612e-04 - val_loss: 4.7502e-05
# Epoch 14/70
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.6079e-04 - val_loss: 3.4090e-05
# Epoch 15/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.5365e-04 - val_loss: 8.4061e-05
# Epoch 16/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.3996e-04 - val_loss: 3.2214e-05
# Epoch 17/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.3619e-04 - val_loss: 5.9033e-05
# Epoch 18/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.3224e-04 - val_loss: 3.2633e-05
# Epoch 19/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.2768e-04 - val_loss: 1.0151e-04
# Epoch 20/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.1893e-04 - val_loss: 4.4063e-05
# Epoch 21/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.1412e-04 - val_loss: 3.8638e-05
# Epoch 22/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.0701e-04 - val_loss: 4.2823e-05
# Epoch 23/70
# 6126/6126 [==============================] - 12s 2ms/step - loss: 1.0695e-04 - val_loss: 6.7825e-05
# Epoch 24/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.0976e-04 - val_loss: 4.4462e-05
# Epoch 25/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 1.0313e-04 - val_loss: 3.6541e-05
# Epoch 26/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 9.9632e-05 - val_loss: 5.5080e-05
# Epoch 27/70
# 6126/6126 [==============================] - 12s 2ms/step - loss:
70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.3557e-05 - val_loss: 2.2231e-05
# Epoch 70/70
# 6126/6126 [==============================] - 13s 2ms/step - loss: 6.0736e-05 - val_loss: 3.0568e-05

# %% [markdown]
# ### Visualize results

# %%
# select which solution to plot
sample_try = 40

p_try = np.tile(p_all[sample_try,:],(n,1))
x_p_try = np.hstack((x_all, p_try))

u_try = data_all_reshaped[:,sample_try]                     # real solution

u_recon = model.predict(x_p_try)*(u_max - u_min) + u_min    # reconstructed solution

fig, ax = plt.subplots(1,2, figsize=(14,5))
ax = ax.ravel()

im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
ax[0].set_title('Real sol');
plt.colorbar(im, ax=ax[0])

im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
plt.colorbar(im, ax=ax[1])
ax[1].set_title('NN sol');

plt.savefig(os.path.join(folder,'Output'))

# %% [markdown]
# ### Loss visualization

# %%
print('________________')
print(f'\nTraining Runtime: {train_time} seconds')
print('________________')

full_loss = hh1.history['loss']
full_val_loss = hh1.history['val_loss']

fig, ax = plt.subplots(1,1, figsize=(8,5))
ax.plot(full_loss, color='dodgerblue')
ax.plot(full_val_loss, color='orange')
ax.set_yscale('log')
ax.set_title('Model Loss')
ax.set_ylabel('loss')
ax.set_xlabel('epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.tight_layout()

plt.savefig(os.path.join(folder,'Model_loss'))
# Out:
# ________________
#
# Training Runtime: 922.7166328430176 seconds
# ________________

# %% [markdown]
# ### (Eventually) perform a second training

# %%
if second_train:

    weights = model.get_weights()

    model.compile(loss=tf.losses.mean_squared_error,
                 # optimizer=tf.optimizers.Adadelta()                 
                 # optimizer=tf.optimizers.Adam(learning_rate=1e-3)   
                  optimizer=tf.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
                 )

    model.set_weights(weights)
    
    t_start = time.time()
    
    hh2 = model.fit(x=train_x_p,
                    y=train_u,
                    epochs=ep2,
                    batch_size=64,
                    validation_data=(test_x_p,test_u))
    
    train_time = time.time() - t_start
# Out:
# Epoch 1/70
# 6126/6126 [==============================] - 12s 2ms/step - loss: 2.5435e-05 - val_loss: 9.1012e-06
# Epoch 2/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.2352e-05 - val_loss: 8.5590e-06
# Epoch 3/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.1431e-05 - val_loss: 7.7581e-06
# Epoch 4/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.0861e-05 - val_loss: 7.7315e-06
# Epoch 5/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 2.0363e-05 - val_loss: 8.4804e-06
# Epoch 6/70
# 6126/6126 [==============================] - 10s 2ms/step - loss: 2.0220e-05 - val_loss: 9.3769e-06
# Epoch 7/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9970e-05 - val_loss: 8.0211e-06
# Epoch 8/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9872e-05 - val_loss: 7.5883e-06
# Epoch 9/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9723e-05 - val_loss: 7.6485e-06
# Epoch 10/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9563e-05 - val_loss: 7.4730e-06
# Epoch 11/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9312e-05 - val_loss: 1.0532e-05
# Epoch 12/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9345e-05 - val_loss: 7.5454e-06
# Epoch 13/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9246e-05 - val_loss: 7.5321e-06
# Epoch 14/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9136e-05 - val_loss: 7.1868e-06
# Epoch 15/70
# 6126/6126 [==============================] - 10s 2ms/step - loss: 1.9080e-05 - val_loss: 7.3262e-06
# Epoch 16/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.9075e-05 - val_loss: 6.9473e-06
# Epoch 17/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.8972e-05 - val_loss: 7.1527e-06
# Epoch 18/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.8863e-05 - val_loss: 7.0963e-06
# Epoch 19/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.8883e-05 - val_loss: 7.5317e-06
# Epoch 20/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.8656e-05 - val_loss: 7.1772e-06
# Epoch 21/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.
70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.7439e-05 - val_loss: 6.8233e-06
# Epoch 70/70
# 6126/6126 [==============================] - 11s 2ms/step - loss: 1.7512e-05 - val_loss: 6.4046e-06

# %%
if second_train:

    sample_try = 40

    p_try = np.tile(p_all[sample_try,:],(n,1))
    x_p_try = np.hstack((x_all, p_try))

    u_try = data_all_reshaped[:,sample_try]

    u_recon = model.predict(x_p_try)*(u_max - u_min) + u_min

    fig, ax = plt.subplots(1,2, figsize=(14,5))
    ax = ax.ravel()

    im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
    ax[0].set_title('Real sol');
    plt.colorbar(im, ax=ax[0])

    im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
    plt.colorbar(im, ax=ax[1])
    ax[1].set_title('NN sol');

    plt.savefig(os.path.join(folder,'Output_second'))

# %%
 if second_train:  
        
    print('________________')
    print(f'\nTraining Runtime: {train_time} seconds')
    print('________________')
    
    full_loss = hh1.history['loss'] + hh2.history['loss']
    full_val_loss = hh1.history['val_loss'] + hh2.history['val_loss']

    fig, ax = plt.subplots(1,1, figsize=(8,5))
    ax.plot(full_loss, color='dodgerblue')
    ax.plot(full_val_loss, color='orange')
    ax.axvline(x=(ep1-1), color='red', linestyle='--')
    ax.set_yscale('log')
    ax.set_title('Model Loss')
    ax.set_ylabel('loss')
    ax.set_xlabel('epoch')
    plt.legend(['Train', 'Test'], loc='best')

    plt.tight_layout()

    plt.savefig(os.path.join(folder,'Model_loss_second'))
# Out:
# ________________
#
# Training Runtime: 766.3723545074463 seconds
# ________________

# %% [markdown]
# ## Save the model

# %%
model.save(os.path.join(folder,'red_model0'))
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Keras_Experiment/red_model0/assets

# %%
folder
# Out:
# '/content/drive/My Drive/Colab Notebooks/Keras_Experiment'

# %% [markdown]
# ## Load a previously saved model

# %%
"""
load_model = tf.keras.models.load_model('red_model04')

sample_try = 40
print(p_all[sample_try,:])
p_try = np.tile(p_all[sample_try,:],(n,1))
x_p_try = np.hstack((x_all, p_try))

u_try = data_all_reshaped[:,sample_try]

u_recon = load_model.predict(x_p_try)*(u_max - u_min) + u_min

fig, ax = plt.subplots(1,2, figsize=(14,5))
ax = ax.ravel()

im = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')
ax[0].set_title('Real sol');
plt.colorbar(im, ax=ax[0])

im = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');
plt.colorbar(im, ax=ax[1])
ax[1].set_title('NN sol');

plt.savefig(os.path.join(folder,'Output'))

"""
# Out:
# "\nload_model = tf.keras.models.load_model('red_model04')\n\nsample_try = 40\nprint(p_all[sample_try,:])\np_try = np.tile(p_all[sample_try,:],(n,1))\nx_p_try = np.hstack((x_all, p_try))\n\nu_try = data_all_reshaped[:,sample_try]\n\nu_recon = load_model.predict(x_p_try)*(u_max - u_min) + u_min\n\nfig, ax = plt.subplots(1,2, figsize=(14,5))\nax = ax.ravel()\n\nim = ax[0].scatter(x_all[:,0], x_all[:,1], c=u_try, cmap='plasma')\nax[0].set_title('Real sol');\nplt.colorbar(im, ax=ax[0])\n\nim = ax[1].scatter(x_all[:,0], x_all[:,1], c=u_recon, cmap='plasma');\nplt.colorbar(im, ax=ax[1])\nax[1].set_title('NN sol');\n\nplt.savefig(os.path.join(folder,'Output'))\n\n"
